# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import os
import math
import re

# %%
names = ['Image','datetime','x_centre[px]','y_centre[px]','x_centre[mm]','y_centre[mm]', 'rel_diff_x[mm]', 'rel_diff_y[mm]']

det_circ = pd.read_excel(r"C:\Users\kwayi\Desktop\School\MasterArbeite_23.24\Codes\Glenn__upssss\Glenn\updated_fitting_centres (1).xlsx", skiprows = 1, names = names)

det_circ
# Out:
#                                 Image            datetime  x_centre[px]  \
# 0   IMG_13029_2024-02-05_10-24-31.jpg 2024-02-05 10:24:31           164
# 1   IMG_13030_2024-02-05_10-29-39.jpg 2024-02-05 10:29:39           163
# 2   IMG_13031_2024-02-05_10-34-47.jpg 2024-02-05 10:34:47           167
# 3   IMG_13032_2024-02-05_10-39-55.jpg 2024-02-05 10:39:55           167
# 4   IMG_13033_2024-02-05_10-45-03.jpg 2024-02-05 10:45:03           164
# ..                                ...                 ...           ...
# 75  IMG_13352_2024-02-06_14-02-41.jpg 2024-02-06 14:02:41           171
# 76  IMG_13353_2024-02-06_14-07-49.jpg 2024-02-06 14:07:49           170
# 77  IMG_13354_2024-02-06_14-12-57.jpg 2024-02-06 14:12:57           170
# 78  IMG_13355_2024-02-06_14-18-05.jpg 2024-02-06 14:18:05           170
# 79  IMG_13356_2024-02-06_14-23-13.jpg 2024-02-06 14:23:13           169
#
#     y_centre[px]  x_centre[mm]  y_centre[mm]  rel_diff_x[mm]  rel_diff_y[mm]
# 0            188     71.683897     82.174223       -0.437097       -4.808066
# 1            189     71.246800     82.611320       -0.437097        0.437097
# 2            195     72.995187     85.233901        1.748388        2.622582
# 3            196     72.995187     85.670998        0.000000        0.437097
# 4            194     71.683897     84.796804       -1.311291       -0.874194
# ..           ...           ...           ...             ...             ...
# 75           184     74.743575     80.425835        0.437097       -3.933872
# 76           192     74.306478     83.922611       -0.437097        3.496775
# 77           189     74.306478     82.611320        0.000000       -1.311291
# 78           192     74.306478     83.922611        0.000000        1.311291
# 79           189     73.869381     82.611320       -0.437097       -1.311291
#
# [80 rows x 8 columns]

# %%
#det_circ=det_circ[['Image','datetime','x_centre[px]','y_centre[px]','x_centre[mm]','y_centre[mm]', 'rel_diff_x[mm]', 'rel_diff_y[mm]']]

# %%
#det_circ['time'] = det_circ['datetime'].apply(lambda x: re.search(r'_(\d{2}-\d{2}-\d{2})', str(x)).group(1))
#det_circ['time'] = det_circ['datetime'].apply(lambda x: re.search(r'_(\d{2}-\d{2}-\d{2})', x).group(1))

#det_circ['time'] = det_circ['datetime'].apply(lambda x: str(x[11:18]))

# %% [markdown]
# Plot a histogram to show the distribution for the differences

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)

# Function to create, save, and display histogram plots
def create_histogram(data, column, title, output_dir):
    plt.figure()
    plt.hist(data[column], bins=20, color='blue', edgecolor='black')
    plt.title(title)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    file_path = os.path.join(output_dir, f"{title}.png")
    plt.savefig(file_path)
    plt.show()  # Display the plot
    plt.close()

# Define the columns and their corresponding titles
columns_titles = {
    'x_centre[mm]': 'Distribution of x_centre[mm]',
    'y_centre[mm]': 'Distribution of y_centre[mm]',
    'rel_diff_x[mm]': 'Distribution of rel_diff_x[mm]',
    'rel_diff_y[mm]': 'Distribution of rel_diff_y[mm]'
}

# Assuming det_circ is the dataframe containing the data
# Generate, save, and display the histogram plots
for column, title in columns_titles.items():
    create_histogram(det_circ, column, title, output_dir)

print("Histogram plots saved and displayed successfully.")
# Out:
# Histogram plots saved and displayed successfully.

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)

# Function to create, save, and display histogram plots in subplots
def create_histogram_subplot(data, columns_titles, output_dir):
    fig, axs = plt.subplots(2, 2, figsize=(7, 5))
    axs = axs.ravel()

    for idx, (column, title) in enumerate(columns_titles.items()):
        axs[idx].hist(data[column], bins=20, color='blue', edgecolor='black')
        axs[idx].set_title(title)
        axs[idx].set_xlabel(column)
        axs[idx].set_ylabel('Number of Images')

    plt.tight_layout()
    file_path = os.path.join(output_dir, "combined_histograms.png")
    plt.savefig(file_path)
    plt.show()  # Display the plot
    plt.close()

# Define the columns and their corresponding titles
columns_titles = {
    'x_centre[mm]': 'Distribution of x_centre[mm]',
    'y_centre[mm]': 'Distribution of y_centre[mm]',
    'rel_diff_x[mm]': 'Distribution of rel_diff_x[mm]',
    'rel_diff_y[mm]': 'Distribution of rel_diff_y[mm]'
}

# Assuming det_circ is the dataframe containing the data
# Generate, save, and display the histogram plots in subplots
create_histogram_subplot(det_circ, columns_titles, output_dir)

print("Histogram plots saved and displayed successfully.")
# Out:
# Histogram plots saved and displayed successfully.

# %%
output_dir = 'path_to_output_directory/plots/'
os.makedirs(output_dir, exist_ok=True)



# Plot 'x_centre[mm]' against 'datetime'
plt.figure(figsize=(8, 5))
plt.plot(det_circ['datetime'], det_circ['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_x[mm] over Time'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_x[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots/rel_diff_xmm_over_Time.png

# %%
output_dir = 'path_to_output_directory/plots/'
os.makedirs(output_dir, exist_ok=True)



# Plot 'x_centre[mm]' against 'datetime'
plt.figure(figsize=(8, 5))
plt.plot(det_circ['datetime'], det_circ['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_y[mm] over Time'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots/rel_diff_ymm_over_Time.png

# %% [markdown]
# Looking into the data further, the plots are going to be broken in parts to provide further understanding

# %% [markdown]
# Since the light went out for the bulb, the first part of the plot will be till 18:00 GMT before it went dark

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots/'
os.makedirs(output_dir, exist_ok=True)

# Filter the dataframe to include only data up to 2024-02-05 18:00:00
end_date = pd.to_datetime('2024-02-05 18:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]

# Create a figure and axis objects for subplots
fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
axs[0].plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
axs[0].set_title('rel_diff_x[mm] over Time (up to 2024-02-05 18:00:00)')
axs[0].set_ylabel('rel_diff_x[mm]')
axs[0].grid(True)

# Plot 'rel_diff_y[mm]' against 'datetime' for the filtered data
axs[1].plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='red')
axs[1].set_title('rel_diff_y[mm] over Time (up to 2024-02-05 18:00:00)')
axs[1].set_ylabel('rel_diff_y[mm]')
axs[1].set_xlabel('Time')
axs[1].grid(True)

# Format the x-axis to show only the time section of the datetime
for ax in axs:
    ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))
    ax.xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)

plt.tight_layout()

# Replace spaces and special characters in the title to create a valid filename
filename = 'rel_diff_combined_x_y_over_time_up_to_2024-02-05_180000.png'
output_file = os.path.join(output_dir, filename)

# Save the combined plot
plt.savefig(output_file, dpi=300)

# Show the combined plot
plt.show()

print(f"Combined plot saved as {output_file}")
# Out:
# Combined plot saved as path_to_output_directory/plots/rel_diff_combined_x_y_over_time_up_to_2024-02-05_180000.png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots/'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data up to 2024-02-05 18:00:00
end_date = pd.to_datetime('2024-02-05 18:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(6, 4))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_x[mm] over Time (up to 2024-02-05 18:00:00)'
plt.title(title)
plt.xlabel('Datetime[s]')
plt.ylabel('rel_diff_x[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots/rel_diff_xmm_over_Time_(up_to_2024-02-05_180000).png

# %%
#Plot of the relative difference between the elements of the y-axis which is in the direction of gravity

# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots/'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data up to 2024-02-05 18:00:00
end_date = pd.to_datetime('2024-02-05 18:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_y[mm] over Time (up to 2024-02-05 18:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots/rel_diff_ymm_over_Time_(up_to_2024-02-05_180000).png

# %%
# Assuming det_circ is the dataframe containing the data

# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots/'
os.makedirs(output_dir, exist_ok=True)

# Filter the dataframe to include only data up to 2024-02-05 18:00:00
end_date = pd.to_datetime('2024-02-05 18:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]

# Create subplots with 2 rows and 1 column
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot 'rel_diff_y[mm]' against 'datetime' for the filtered data in the first subplot
axs[0].plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
axs[0].set_title('rel_diff_y[mm] over Time (up to 2024-02-05 18:00:00)')
axs[0].set_xlabel('Datetime')
axs[0].set_ylabel('rel_diff_y[mm]')
axs[0].tick_params(axis='x', rotation=45)
axs[0].grid(True)
axs[0].xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
axs[0].xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data in the second subplot
axs[1].plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
axs[1].set_title('rel_diff_x[mm] over Time (up to 2024-02-05 18:00:00)')
axs[1].set_xlabel('Datetime')
axs[1].set_ylabel('rel_diff_x[mm]')
axs[1].tick_params(axis='x', rotation=45)
axs[1].grid(True)
axs[1].xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
axs[1].xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the combined plot as an image
filename = "rel_diff_combined_plot_up_to_2024-02-05_18_00_00.png"
output_file = os.path.join(output_dir, filename)
plt.savefig(output_file, dpi=300)

# Show the combined plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots/rel_diff_combined_plot_up_to_2024-02-05_18_00_00.png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)



# Filter the dataframe to include only data up to 2024-02-05 12:00:00
end_date = pd.to_datetime('2024-02-05 12:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_x[mm] over Time (up to 2024-02-05 12:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_x[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_xmm_over_Time_(up_to_2024-02-05_120000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data from 2024-02-05 12:00:00 to 2024-02-05 13:30:00
start_date = pd.to_datetime('2024-02-05 12:00:00')
end_date = pd.to_datetime('2024-02-05 13:30:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_y[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_y[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_y[mm] over Time (from 2024-02-05 12:00:00 to 2024-02-05 13:30:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_ymm_over_Time_(from_2024-02-05_120000_to_2024-02-05_133000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)



# Filter the dataframe to include only data up to 2024-02-05 12:00:00
end_date = pd.to_datetime('2024-02-05 12:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_y[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_y[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_y[mm] over Time (up to 2024-02-05 12:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_ymm_over_Time_(up_to_2024-02-05_120000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)

# Initialize the subplot figure
fig, axs = plt.subplots(3, 1, figsize=(10, 8))

# First plot: rel_diff_x[mm] up to 2024-02-05 12:00:00
end_date = pd.to_datetime('2024-02-05 12:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

axs[0].plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
axs[0].set_title('rel_diff_x[mm] over Time (up to 2024-02-05 12:00:00)')
axs[0].set_ylabel('rel_diff_x[mm]')
axs[0].grid(True)

textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
axs[0].text(0.75, 0.75, textstr, transform=axs[0].transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Second plot: rel_diff_x[mm] from 2024-02-05 12:00:00 to 2024-02-05 13:30:00
start_date = pd.to_datetime('2024-02-05 12:00:00')
end_date = pd.to_datetime('2024-02-05 13:30:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

axs[1].plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
axs[1].set_title('rel_diff_x[mm] over Time (from 2024-02-05 12:00:00 to 2024-02-05 13:30:00)')
axs[1].set_ylabel('rel_diff_x[mm]')
axs[1].grid(True)

textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
axs[1].text(0.75, 0.75, textstr, transform=axs[1].transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Third plot: rel_diff_x[mm] from 2024-02-05 13:30:00 to 2024-02-05 16:00:00
start_date = pd.to_datetime('2024-02-05 13:30:00')
end_date = pd.to_datetime('2024-02-05 16:00:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

axs[2].plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
axs[2].set_title('rel_diff_x[mm] over Time (from 2024-02-05 13:30:00 to 2024-02-05 16:00:00)')
axs[2].set_xlabel('Time')
axs[2].set_ylabel('rel_diff_x[mm]')
axs[2].grid(True)

textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
axs[2].text(0.75, 0.75, textstr, transform=axs[2].transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Format the x-axis to show only the time part of datetime but hide the labels and ticks on all subplots
for ax in axs:
    ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))
    ax.xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
    plt.setp(ax.get_xticklabels(), visible=False)
    plt.setp(ax.get_xticklines(), visible=False)

plt.tight_layout()

# Save the combined plot
filename = 'combined_rel_diff_x_plots_no_x_labels.png'
output_file = os.path.join(output_dir, filename)
plt.savefig(output_file, dpi=300)

# Show the combined plot
plt.show()

print(f"Combined plot saved as {output_file}")
# Out:
# Combined plot saved as path_to_output_directory/plots\combined_rel_diff_x_plots_no_x_labels.png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)

# Initialize the subplot figure with 3 rows and 1 column
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# First time block: up to 2024-02-05 12:00:00
end_date = pd.to_datetime('2024-02-05 12:00:00')
filtered_data_x = det_circ[det_circ['datetime'] <= end_date]
filtered_data_y = det_circ[det_circ['datetime'] <= end_date]

# Plot rel_diff_x[mm] and rel_diff_y[mm] on the same subplot
std_dev_x = np.std(filtered_data_x['rel_diff_x[mm]'])
std_error_x = std_dev_x / np.sqrt(len(filtered_data_x['rel_diff_x[mm]']))
std_dev_y = np.std(filtered_data_y['rel_diff_y[mm]'])
std_error_y = std_dev_y / np.sqrt(len(filtered_data_y['rel_diff_y[mm]']))

axs[0].plot(filtered_data_x['datetime'], filtered_data_x['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue', label='rel_diff_x[mm]')
axs[0].plot(filtered_data_y['datetime'], filtered_data_y['rel_diff_y[mm]'], marker='o', linestyle='-', color='red', label='rel_diff_y[mm]')
axs[0].set_title('Relative Differences (up to 2024-02-05 12:00:00)')
axs[0].set_ylabel('Relative change (mm)')
axs[0].grid(True)
axs[0].legend()
textstr = f'Std dev X: {std_dev_x:.2f}, Y: {std_dev_y:.2f}\nStd Error X: {std_error_x:.2f}, Y: {std_error_y:.2f}'
axs[0].text(0.05, 0.05, textstr, transform=axs[0].transAxes, fontsize=12, verticalalignment='bottom', bbox=dict(facecolor='white', alpha=0.5))

# Second time block: from 2024-02-05 12:00:00 to 2024-02-05 13:30:00
start_date = pd.to_datetime('2024-02-05 12:00:00')
end_date = pd.to_datetime('2024-02-05 13:30:00')
filtered_data_x = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
filtered_data_y = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Plot rel_diff_x[mm] and rel_diff_y[mm] on the same subplot
std_dev_x = np.std(filtered_data_x['rel_diff_x[mm]'])
std_error_x = std_dev_x / np.sqrt(len(filtered_data_x['rel_diff_x[mm]']))
std_dev_y = np.std(filtered_data_y['rel_diff_y[mm]'])
std_error_y = std_dev_y / np.sqrt(len(filtered_data_y['rel_diff_y[mm]']))

axs[1].plot(filtered_data_x['datetime'], filtered_data_x['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue', label='rel_diff_x[mm]')
axs[1].plot(filtered_data_y['datetime'], filtered_data_y['rel_diff_y[mm]'], marker='o', linestyle='-', color='red', label='rel_diff_y[mm]')
axs[1].set_title('Relative Differences (2024-02-05 12:00:00 to 2024-02-05 13:30:00)')
axs[1].set_ylabel('Relative change (mm)')
axs[1].grid(True)
axs[1].legend()
textstr = f'Std dev X: {std_dev_x:.2f}, Y: {std_dev_y:.2f}\nStd Error X: {std_error_x:.2f}, Y: {std_error_y:.2f}'
axs[1].text(0.05, 0.05, textstr, transform=axs[1].transAxes, fontsize=12, verticalalignment='bottom', bbox=dict(facecolor='white', alpha=0.5))

# Third time block: from 2024-02-05 13:30:00 to 2024-02-05 16:00:00
start_date = pd.to_datetime('2024-02-05 13:30:00')
end_date = pd.to_datetime('2024-02-05 16:00:00')
filtered_data_x = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
filtered_data_y = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Plot rel_diff_x[mm] and rel_diff_y[mm] on the same subplot
std_dev_x = np.std(filtered_data_x['rel_diff_x[mm]'])
std_error_x = std_dev_x / np.sqrt(len(filtered_data_x['rel_diff_x[mm]']))
std_dev_y = np.std(filtered_data_y['rel_diff_y[mm]'])
std_error_y = std_dev_y / np.sqrt(len(filtered_data_y['rel_diff_y[mm]']))

axs[2].plot(filtered_data_x['datetime'], filtered_data_x['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue', label='rel_diff_x[mm]')
axs[2].plot(filtered_data_y['datetime'], filtered_data_y['rel_diff_y[mm]'], marker='o', linestyle='-', color='red', label='rel_diff_y[mm]')
axs[2].set_title('Relative Differences (2024-02-05 13:30:00 to 2024-02-05 16:00:00)')
axs[2].set_ylabel('Relative change (mm)')
axs[2].set_xlabel('Time(s)')
axs[2].grid(True)
axs[2].legend()
textstr = f'Std dev X: {std_dev_x:.2f}, Y: {std_dev_y:.2f}\nStd Error X: {std_error_x:.2f}, Y: {std_error_y:.2f}'
axs[2].text(0.05, 0.05, textstr, transform=axs[2].transAxes, fontsize=12, verticalalignment='bottom', bbox=dict(facecolor='white', alpha=0.5))

# Hide the x-axis labels
for ax in axs[:-1]:  # Hide labels for all but the last subplot
    ax.xaxis.set_ticklabels([])
    
# Format the x-axis to show only the time part of datetime
for ax in axs:
    ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))
    ax.xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the combined plot
filename = 'combined_rel_diff_x_y_plots.png'
output_file = os.path.join(output_dir, filename)
plt.savefig(output_file, dpi=300)

# Show the combined plot
plt.show()

print(f"Combined plot saved as {output_file}")
# Out:
# Combined plot saved as path_to_output_directory/plots\combined_rel_diff_x_y_plots.png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)

# Initialize the subplot figure
fig, axs = plt.subplots(3, 1, figsize=(10, 8))

# First plot: rel_diff_y[mm] up to 2024-02-05 12:00:00
end_date = pd.to_datetime('2024-02-05 12:00:00')
filtered_data = det_circ[det_circ['datetime'] <= end_date]
std_dev = np.std(filtered_data['rel_diff_y[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_y[mm]']))

axs[0].plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
axs[0].set_title('rel_diff_y[mm] over Time (up to 2024-02-05 12:00:00)')
axs[0].set_ylabel('rel_diff_y[mm]')
axs[0].grid(True)

textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
axs[0].text(0.75, 0.75, textstr, transform=axs[0].transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Second plot: rel_diff_y[mm] from 2024-02-05 12:00:00 to 2024-02-05 13:30:00
start_date = pd.to_datetime('2024-02-05 12:00:00')
end_date = pd.to_datetime('2024-02-05 13:30:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
std_dev = np.std(filtered_data['rel_diff_y[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_y[mm]']))

axs[1].plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
axs[1].set_title('rel_diff_y[mm] over Time (from 2024-02-05 12:00:00 to 2024-02-05 13:30:00)')
axs[1].set_ylabel('rel_diff_y[mm]')
axs[1].grid(True)

textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
axs[1].text(0.75, 0.75, textstr, transform=axs[1].transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Third plot: rel_diff_y[mm] from 2024-02-05 13:30:00 to 2024-02-05 16:00:00
start_date = pd.to_datetime('2024-02-05 13:30:00')
end_date = pd.to_datetime('2024-02-05 16:00:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
std_dev = np.std(filtered_data['rel_diff_y[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_y[mm]']))

axs[2].plot(filtered_data['datetime'], filtered_data['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
axs[2].set_title('rel_diff_y[mm] over Time (from 2024-02-05 13:30:00 to 2024-02-05 16:00:00)')
axs[2].set_xlabel('Time(s)')
axs[2].set_ylabel('rel_diff_y[mm]')
axs[2].grid(True)

textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
axs[2].text(0.75, 0.75, textstr, transform=axs[2].transAxes, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Format the x-axis to show only the time part of datetime but hide the labels and ticks on all subplots
for ax in axs:
    ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))
    ax.xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
    plt.setp(ax.get_xticklabels(), visible=False)
    plt.setp(ax.get_xticklines(), visible=False)

plt.tight_layout()

# Save the combined plot
filename = 'combined_rel_diff_y_plots_no_x_labels.png'
output_file = os.path.join(output_dir, filename)
plt.savefig(output_file, dpi=300)

# Show the combined plot
plt.show()

print(f"Combined plot saved as {output_file}")
# Out:
# Combined plot saved as path_to_output_directory/plots\combined_rel_diff_y_plots_no_x_labels.png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data from 2024-02-05 12:00:00 to 2024-02-05 13:30:00
start_date = pd.to_datetime('2024-02-05 12:00:00')
end_date = pd.to_datetime('2024-02-05 13:30:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_x[mm] over Time (from 2024-02-05 12:00:00 to 2024-02-05 13:30:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_x[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_xmm_over_Time_(from_2024-02-05_120000_to_2024-02-05_133000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data from 2024-02-05 13:30:00 to 2024-02-05 16:00:00
start_date = pd.to_datetime('2024-02-05 13:30:00')
end_date = pd.to_datetime('2024-02-05 16:00:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_y[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_y[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_y[mm] over Time (from 2024-02-05 13:30:00 to 2024-02-05 16:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_ymm_over_Time_(from_2024-02-05_133000_to_2024-02-05_160000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data from 2024-02-05 13:30:00 to 2024-02-05 16:00:00
start_date = pd.to_datetime('2024-02-05 13:30:00')
end_date = pd.to_datetime('2024-02-05 16:00:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_x[mm] over Time (from 2024-02-05 13:30:00 to 2024-02-05 16:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_x[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_xmm_over_Time_(from_2024-02-05_133000_to_2024-02-05_160000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'
os.makedirs(output_dir, exist_ok=True)


# Filter the dataframe to include only data from 2024-02-06 10:00:00 to 2024-02-06 16:00:00
start_date = pd.to_datetime('2024-02-06 10:00:00')
end_date = pd.to_datetime('2024-02-06 16:00:00')
filtered_data = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_data['rel_diff_x[mm]'])
std_error = std_dev / np.sqrt(len(filtered_data['rel_diff_x[mm]']))

# Plot 'rel_diff_x[mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_data['datetime'], filtered_data['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title = 'rel_diff_x[mm] over Time (from 2024-02-06 10:00:00 to 2024-02-06 16:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_x[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# Plot saved as path_to_output_directory/plots\rel_diff_xmm_over_Time_(from_2024-02-06_100000_to_2024-02-06_160000).png

# %% [markdown]
# * With most of the measurements being below 5mm and a few more between 6 to 10mm, a thresold value of 7mm is set and any measurement greater than 7mm is set as an outlier.
#
# * Distance from the target to the camera station is 80m
#
# * Let every outlier be represented by the variable v

# %%
outliers_y = det_circ[(det_circ['rel_diff_y[mm]'] < -10) | (det_circ['rel_diff_y[mm]'] > 10)]

# Count the number of outliers
num_outliers_y = len(outliers_y)

# List the outlier values
outlier_values_y = outliers_y['rel_diff_y[mm]'].tolist()

print(f"Number of outliers_y:",  num_outliers_y)
print(f"Outlier values_y: ", outlier_values_y)
# Out:
# Number of outliers_y: 12
# Outlier values_y:  [-18.35807106, 15.73548948, -21.8548465, 24.47742808, -32.34517282000001, 32.34517281999999, -16.17258640999999, 16.17258640999999, -17.04678027, 22.29194343, -12.67581097, 13.98710176]

# %%
outlier_values[4]
# Out:
# 22.29194343

# %%
dist = 80
v_y1 = outlier_values[0]
v_y2 = outlier_values[1]
v_y3 = outlier_values[2]
v_y4 = outlier_values[3]
v_y5 = outlier_values[4]
v_y6 = outlier_values[5]

ang_y1 = math.degrees(math.atan(( v_y1/1000)/dist))

ang_y2 = math.degrees(math.atan(( v_y2/1000)/dist))

ang_y3 = math.degrees(math.atan(( v_y3/1000)/dist))

ang_y4 = math.degrees(math.atan(( v_y4/1000)/dist))

ang_y5 = math.degrees(math.atan(( v_y5/1000)/dist))

ang_y6 = math.degrees(math.atan(( v_y6/1000)/dist))


print(' angular diff_y1 = ', ang_y1)
print(' angular diff_y2 = ', ang_y2)
print(' angular diff_y3 = ', ang_y3)
print(' angular diff_y4 = ', ang_y4)
print(' angular diff_y5 = ', ang_y5)
print(' angular diff_y6 = ', ang_y6)
# Out:
#  angular diff_y1 =  0.011269714051870673
#  angular diff_y2 =  0.017530665981935457
#  angular diff_y3 =  0.02316552236529886
#  angular diff_y4 =  0.011582761656008887
#  angular diff_y5 =  0.015965428032828143
#  angular diff_y6 =  0.010017523628776195

# %%
# Identify outliers in 'rel_diff_x[mm]' where values are greater than 7mm
outliers = det_circ[det_circ['rel_diff_x[mm]'] > 7]

# Count the number of outliers
num_outliers = len(outliers)

# List the outlier values
outlier_values = outliers['rel_diff_x[mm]'].tolist()

print(f"Number of outliers: {num_outliers}")
print(f"Outlier values: {outlier_values}")
# Out:
# Number of outliers: 4
# Outlier values: [9.17903553, 8.741938599999997, 10.05322939, 10.05322939]

# %% [markdown]
# Calculate the angular differencial for the outliers

# %%
dist = 80
v_x1 = 9.17903553
v_x2 = 8.741938599999997
v_x3 = 10.05322939
v_x4 = 10.05322939

ang_x1 = math.degrees(math.atan((v_x1/1000)/80))

ang_x2 = math.degrees(math.atan((v_x2/1000)/80))

ang_x3 = math.degrees(math.atan((v_x3/1000)/80))

ang_x4 = math.degrees(math.atan((v_x4/1000)/80))


print(' angular diff_x1 = ', ang_x1)
print(' angular diff_x2 = ', ang_x2)
print(' angular diff_x3 = ', ang_x3)
print(' angular diff_x4 = ', ang_x4)

values = np.array([ang_x1,ang_x2,ang_x3,ang_x4])
mean_ang = values.mean()

print(' mean angular difference = ', mean_ang)
# Out:
#  angular diff1 =  0.006573999919521904
#  angular diff2 =  0.006260952306860912
#  angular diff3 =  0.007200095143647706
#  angular diff4 =  0.007200095143647706
#  mean angular difference =  0.006808785628419556

# %% [markdown]
# the angles in degrees are very small but still has an effect on the results being that, a 10mm(approximately) movement is very huge.
# + This is approximately 0,007 degrees but also clearly shows there is significant movement which can alter the accuracy output of the work
# + this could be as a result of movement at the base station resulting from the build using bots and nuts succumbing to some sort of vibrations in the end. If after further investigations this
# seems to be the case, then the build must be changed or the location for the base should be changed.
#
# - Rec: Have a ref cam on a stable ground to probably have a change in the cam position under the bridge. definition of stability of civil engineers varies to that of accuracy dependant facts

# %%
#output_file = 'Updated_hydro_XT.xlsx'
#hydro.to_excel(output_file, index=False)

#hydro['Datum'] = hydro['Datum'].astype(str).str.replace('.', '-')
#hydro

# %%
# Load the new Excel file
file_path = r"C:\Users\kwayi\Desktop\School\MasterArbeite_23.24\Codes\Glenn__upssss\Glenn\Rotated_hydro_XT.csv"
hydro1 = pd.read_csv(file_path, skiprows= 0, sep=',')
hydro1.dropna

#hydro1=hydro1.iloc[::-1]
hydro1
# Out:
#                 Datum  dH [mm]  dH [mm].1  dH [mm].2  dH [mm].3  dH [mm].4  \
# 0    05.02.2024 00:00  -7.8909    -7.8279    -7.6179    -7.2689    -8.3529
# 1    05.02.2024 00:05  -7.5994    -7.5814    -7.3754    -7.0484    -8.0824
# 2    05.02.2024 00:10  -8.5274    -8.4284    -8.2854    -7.8744    -8.9234
# 3    05.02.2024 00:15  -7.9672    -7.9502    -7.7552    -7.4212    -8.5382
# 4    05.02.2024 00:20  -7.8025    -7.8015    -7.6255    -7.2145    -8.2065
# ..                ...      ...        ...        ...        ...        ...
# 571  06.02.2024 23:35  -2.6469    -2.6789    -2.5089    -2.0979    -2.9969
# 572  06.02.2024 23:40  -2.8193    -2.6943    -2.6163    -2.2293    -3.2293
# 573  06.02.2024 23:45  -2.4433    -2.8673    -2.3233    -1.8163    -2.9873
# 574  06.02.2024 23:50  -2.9723    -3.1113    -2.9533    -2.5203    -3.5423
# 575  06.02.2024 23:55  -2.3047    -2.3917    -2.1387    -1.7417    -2.7577
#
#      dH [mm].5  dH [mm].6  dH [mm].7  dH [mm].8  ...  dH [mm].53  dH [mm].54  \
# 0      -7.3319      0.333     -0.419    -6.3959  ...     -1.9529      0.3781
# 1      -7.0414      0.274     -0.503    -6.1574  ...     -2.0714      0.4066
# 2      -7.8884      0.024     -0.663    -6.9744  ...     -2.1804      0.2266
# 3      -7.4452      0.268     -0.444    -6.5162  ...     -1.8012      0.3828
# 4      -7.2215      0.324     -0.344    -6.3255  ...     -1.8055      0.5795
# ..         ...        ...        ...        ...  ...         ...         ...
# 571    -2.2719      0.764     -0.317    -1.2339  ...      4.9121      7.9031
# 572    -2.4873      0.632     -0.813    -1.3973  ...      4.3637      7.5097
# 573    -1.9803      0.634     -0.514    -0.8533  ...      4.7557      7.7517
# 574    -2.8353      0.728     -0.489    -1.7973  ...      4.1457      7.4977
# 575    -2.0247      0.891     -0.109    -1.0157  ...      4.6643      7.3103
#
#      dH [mm].55  dH [mm].56  dH [mm].57  dH [mm].58  dH [mm].59  dH [mm].60  \
# 0        0.2881     -2.4609     -3.3739     -6.8949     -7.6899     -5.6699
# 1        0.4086     -2.3594     -2.8924     -6.6084     -7.4224     -5.4784
# 2        0.0126     -2.7084     -3.4994     -7.5524     -8.1764     -6.3494
# 3        0.1978     -2.4862     -3.4232     -6.9332     -7.5962     -5.6452
# 4        0.1185     -2.5285     -3.2975     -6.8865     -7.5005     -5.7745
# ..          ...         ...         ...         ...         ...         ...
# 571      6.8491      3.3451      2.0291     -1.7769     -2.0969      0.0691
# 572      6.6157      3.0587      2.8197     -1.8443     -2.5513     -0.2993
# 573      6.9107      3.2937      2.4917     -1.4863     -2.1323      0.0667
# 574      6.6017      3.2837      2.2857     -2.0593     -2.7763     -0.6063
# 575      7.0343      3.5233      2.6883     -1.3367     -2.0177      0.0193
#
#      dH [mm].61  Unnamed: 63
# 0       -7.2519          NaN
# 1       -6.9634          NaN
# 2       -7.8864          NaN
# 3       -7.2462          NaN
# 4       -7.1355          NaN
# ..          ...          ...
# 571     -1.9869          NaN
# 572     -2.1303          NaN
# 573     -1.6903          NaN
# 574     -2.3223          NaN
# 575     -1.6187          NaN
#
# [576 rows x 64 columns]

# %%
hydro1['datetime'] = hydro1['Datum']

hydro1
# Out:
#                 Datum  dH [mm]  dH [mm].1  dH [mm].2  dH [mm].3  dH [mm].4  \
# 0    05.02.2024 00:00  -7.8909    -7.8279    -7.6179    -7.2689    -8.3529
# 1    05.02.2024 00:05  -7.5994    -7.5814    -7.3754    -7.0484    -8.0824
# 2    05.02.2024 00:10  -8.5274    -8.4284    -8.2854    -7.8744    -8.9234
# 3    05.02.2024 00:15  -7.9672    -7.9502    -7.7552    -7.4212    -8.5382
# 4    05.02.2024 00:20  -7.8025    -7.8015    -7.6255    -7.2145    -8.2065
# ..                ...      ...        ...        ...        ...        ...
# 571  06.02.2024 23:35  -2.6469    -2.6789    -2.5089    -2.0979    -2.9969
# 572  06.02.2024 23:40  -2.8193    -2.6943    -2.6163    -2.2293    -3.2293
# 573  06.02.2024 23:45  -2.4433    -2.8673    -2.3233    -1.8163    -2.9873
# 574  06.02.2024 23:50  -2.9723    -3.1113    -2.9533    -2.5203    -3.5423
# 575  06.02.2024 23:55  -2.3047    -2.3917    -2.1387    -1.7417    -2.7577
#
#      dH [mm].5  dH [mm].6  dH [mm].7  dH [mm].8  ...  dH [mm].54  dH [mm].55  \
# 0      -7.3319      0.333     -0.419    -6.3959  ...      0.3781      0.2881
# 1      -7.0414      0.274     -0.503    -6.1574  ...      0.4066      0.4086
# 2      -7.8884      0.024     -0.663    -6.9744  ...      0.2266      0.0126
# 3      -7.4452      0.268     -0.444    -6.5162  ...      0.3828      0.1978
# 4      -7.2215      0.324     -0.344    -6.3255  ...      0.5795      0.1185
# ..         ...        ...        ...        ...  ...         ...         ...
# 571    -2.2719      0.764     -0.317    -1.2339  ...      7.9031      6.8491
# 572    -2.4873      0.632     -0.813    -1.3973  ...      7.5097      6.6157
# 573    -1.9803      0.634     -0.514    -0.8533  ...      7.7517      6.9107
# 574    -2.8353      0.728     -0.489    -1.7973  ...      7.4977      6.6017
# 575    -2.0247      0.891     -0.109    -1.0157  ...      7.3103      7.0343
#
#      dH [mm].56  dH [mm].57  dH [mm].58  dH [mm].59  dH [mm].60  dH [mm].61  \
# 0       -2.4609     -3.3739     -6.8949     -7.6899     -5.6699     -7.2519
# 1       -2.3594     -2.8924     -6.6084     -7.4224     -5.4784     -6.9634
# 2       -2.7084     -3.4994     -7.5524     -8.1764     -6.3494     -7.8864
# 3       -2.4862     -3.4232     -6.9332     -7.5962     -5.6452     -7.2462
# 4       -2.5285     -3.2975     -6.8865     -7.5005     -5.7745     -7.1355
# ..          ...         ...         ...         ...         ...         ...
# 571      3.3451      2.0291     -1.7769     -2.0969      0.0691     -1.9869
# 572      3.0587      2.8197     -1.8443     -2.5513     -0.2993     -2.1303
# 573      3.2937      2.4917     -1.4863     -2.1323      0.0667     -1.6903
# 574      3.2837      2.2857     -2.0593     -2.7763     -0.6063     -2.3223
# 575      3.5233      2.6883     -1.3367     -2.0177      0.0193     -1.6187
#
#      Unnamed: 63          datetime
# 0            NaN  05.02.2024 00:00
# 1            NaN  05.02.2024 00:05
# 2            NaN  05.02.2024 00:10
# 3            NaN  05.02.2024 00:15
# 4            NaN  05.02.2024 00:20
# ..           ...               ...
# 571          NaN  06.02.2024 23:35
# 572          NaN  06.02.2024 23:40
# 573          NaN  06.02.2024 23:45
# 574          NaN  06.02.2024 23:50
# 575          NaN  06.02.2024 23:55
#
# [576 rows x 65 columns]

# %%
hydro1['datetime'] = hydro1['datetime'].astype(str).str.replace('.', '-')
hydro1
# Out:
# c:\Users\kwayi\anaconda3\envs\hs_nb_env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
#                 Datum  dH [mm]  dH [mm].1  dH [mm].2  dH [mm].3  dH [mm].4  \
# 0    05.02.2024 00:00  -7.8909    -7.8279    -7.6179    -7.2689    -8.3529
# 1    05.02.2024 00:05  -7.5994    -7.5814    -7.3754    -7.0484    -8.0824
# 2    05.02.2024 00:10  -8.5274    -8.4284    -8.2854    -7.8744    -8.9234
# 3    05.02.2024 00:15  -7.9672    -7.9502    -7.7552    -7.4212    -8.5382
# 4    05.02.2024 00:20  -7.8025    -7.8015    -7.6255    -7.2145    -8.2065
# ..                ...      ...        ...        ...        ...        ...
# 571  06.02.2024 23:35  -2.6469    -2.6789    -2.5089    -2.0979    -2.9969
# 572  06.02.2024 23:40  -2.8193    -2.6943    -2.6163    -2.2293    -3.2293
# 573  06.02.2024 23:45  -2.4433    -2.8673    -2.3233    -1.8163    -2.9873
# 574  06.02.2024 23:50  -2.9723    -3.1113    -2.9533    -2.5203    -3.5423
# 575  06.02.2024 23:55  -2.3047    -2.3917    -2.1387    -1.7417    -2.7577
#
#      dH [mm].5  dH [mm].6  dH [mm].7  dH [mm].8  ...  dH [mm].54  dH [mm].55  \
# 0      -7.3319      0.333     -0.419    -6.3959  ...      0.3781      0.2881
# 1      -7.0414      0.274     -0.503    -6.1574  ...      0.4066      0.4086
# 2      -7.8884      0.024     -0.663    -6.9744  ...      0.2266      0.0126
# 3      -7.4452      0.268     -0.444    -6.5162  ...      0.3828      0.1978
# 4      -7.2215      0.324     -0.344    -6.3255  ...      0.5795      0.1185
# ..         ...        ...        ...        ...  ...         ...         ...
# 571    -2.2719      0.764     -0.317    -1.2339  ...      7.9031      6.8491
# 572    -2.4873      0.632     -0.813    -1.3973  ...      7.5097      6.6157
# 573    -1.9803      0.634     -0.514    -0.8533  ...      7.7517      6.9107
# 574    -2.8353      0.728     -0.489    -1.7973  ...      7.4977      6.6017
# 575    -2.0247      0.891     -0.109    -1.0157  ...      7.3103      7.0343
#
#      dH [mm].56  dH [mm].57  dH [mm].58  dH [mm].59  dH [mm].60  dH [mm].61  \
# 0       -2.4609     -3.3739     -6.8949     -7.6899     -5.6699     -7.2519
# 1       -2.3594     -2.8924     -6.6084     -7.4224     -5.4784     -6.9634
# 2       -2.7084     -3.4994     -7.5524     -8.1764     -6.3494     -7.8864
# 3       -2.4862     -3.4232     -6.9332     -7.5962     -5.6452     -7.2462
# 4       -2.5285     -3.2975     -6.8865     -7.5005     -5.7745     -7.1355
# ..          ...         ...         ...         ...         ...         ...
# 571      3.3451      2.0291     -1.7769     -2.0969      0.0691     -1.9869
# 572      3.0587      2.8197     -1.8443     -2.5513     -0.2993     -2.1303
# 573      3.2937      2.4917     -1.4863     -2.1323      0.0667     -1.6903
# 574      3.2837      2.2857     -2.0593     -2.7763     -0.6063     -2.3223
# 575      3.5233      2.6883     -1.3367     -2.0177      0.0193     -1.6187
#
#      Unnamed: 63          datetime
# 0            NaN  05-02-2024 00:00
# 1            NaN  05-02-2024 00:05
# 2            NaN  05-02-2024 00:10
# 3            NaN  05-02-2024 00:15
# 4            NaN  05-02-2024 00:20
# ..           ...               ...
# 571          NaN  06-02-2024 23:35
# 572          NaN  06-02-2024 23:40
# 573          NaN  06-02-2024 23:45
# 574          NaN  06-02-2024 23:50
# 575          NaN  06-02-2024 23:55
#
# [576 rows x 65 columns]

# %%
# Convert the 'Datum' column to datetime data type with the original format
hydro1['datetime'] = pd.to_datetime(hydro1['datetime'], format='%d-%m-%Y %H:%M')

# Reformat the 'Datum' column to the desired format
hydro1['datetime'] = hydro1['datetime'].dt.strftime('%Y-%m-%d %H:%M')

# Convert back to datetime to plot correctly
hydro1['datetime'] = pd.to_datetime(hydro1['datetime'], format='%Y-%m-%d %H:%M')

#hydro1.set_index('datetime', inplace=True)

hydro1
# Out:
#                 Datum  dH [mm]  dH [mm].1  dH [mm].2  dH [mm].3  dH [mm].4  \
# 0    05.02.2024 00:00  -7.8909    -7.8279    -7.6179    -7.2689    -8.3529
# 1    05.02.2024 00:05  -7.5994    -7.5814    -7.3754    -7.0484    -8.0824
# 2    05.02.2024 00:10  -8.5274    -8.4284    -8.2854    -7.8744    -8.9234
# 3    05.02.2024 00:15  -7.9672    -7.9502    -7.7552    -7.4212    -8.5382
# 4    05.02.2024 00:20  -7.8025    -7.8015    -7.6255    -7.2145    -8.2065
# ..                ...      ...        ...        ...        ...        ...
# 571  06.02.2024 23:35  -2.6469    -2.6789    -2.5089    -2.0979    -2.9969
# 572  06.02.2024 23:40  -2.8193    -2.6943    -2.6163    -2.2293    -3.2293
# 573  06.02.2024 23:45  -2.4433    -2.8673    -2.3233    -1.8163    -2.9873
# 574  06.02.2024 23:50  -2.9723    -3.1113    -2.9533    -2.5203    -3.5423
# 575  06.02.2024 23:55  -2.3047    -2.3917    -2.1387    -1.7417    -2.7577
#
#      dH [mm].5  dH [mm].6  dH [mm].7  dH [mm].8  ...  dH [mm].54  dH [mm].55  \
# 0      -7.3319      0.333     -0.419    -6.3959  ...      0.3781      0.2881
# 1      -7.0414      0.274     -0.503    -6.1574  ...      0.4066      0.4086
# 2      -7.8884      0.024     -0.663    -6.9744  ...      0.2266      0.0126
# 3      -7.4452      0.268     -0.444    -6.5162  ...      0.3828      0.1978
# 4      -7.2215      0.324     -0.344    -6.3255  ...      0.5795      0.1185
# ..         ...        ...        ...        ...  ...         ...         ...
# 571    -2.2719      0.764     -0.317    -1.2339  ...      7.9031      6.8491
# 572    -2.4873      0.632     -0.813    -1.3973  ...      7.5097      6.6157
# 573    -1.9803      0.634     -0.514    -0.8533  ...      7.7517      6.9107
# 574    -2.8353      0.728     -0.489    -1.7973  ...      7.4977      6.6017
# 575    -2.0247      0.891     -0.109    -1.0157  ...      7.3103      7.0343
#
#      dH [mm].56  dH [mm].57  dH [mm].58  dH [mm].59  dH [mm].60  dH [mm].61  \
# 0       -2.4609     -3.3739     -6.8949     -7.6899     -5.6699     -7.2519
# 1       -2.3594     -2.8924     -6.6084     -7.4224     -5.4784     -6.9634
# 2       -2.7084     -3.4994     -7.5524     -8.1764     -6.3494     -7.8864
# 3       -2.4862     -3.4232     -6.9332     -7.5962     -5.6452     -7.2462
# 4       -2.5285     -3.2975     -6.8865     -7.5005     -5.7745     -7.1355
# ..          ...         ...         ...         ...         ...         ...
# 571      3.3451      2.0291     -1.7769     -2.0969      0.0691     -1.9869
# 572      3.0587      2.8197     -1.8443     -2.5513     -0.2993     -2.1303
# 573      3.2937      2.4917     -1.4863     -2.1323      0.0667     -1.6903
# 574      3.2837      2.2857     -2.0593     -2.7763     -0.6063     -2.3223
# 575      3.5233      2.6883     -1.3367     -2.0177      0.0193     -1.6187
#
#      Unnamed: 63            datetime
# 0            NaN 2024-02-05 00:00:00
# 1            NaN 2024-02-05 00:05:00
# 2            NaN 2024-02-05 00:10:00
# 3            NaN 2024-02-05 00:15:00
# 4            NaN 2024-02-05 00:20:00
# ..           ...                 ...
# 571          NaN 2024-02-06 23:35:00
# 572          NaN 2024-02-06 23:40:00
# 573          NaN 2024-02-06 23:45:00
# 574          NaN 2024-02-06 23:50:00
# 575          NaN 2024-02-06 23:55:00
#
# [576 rows x 65 columns]

# %%
#hydro1.drop(columns=['Datum'], inplace=True)

hydro1


# Define the output directory and file name
output_dir = r"C:\Users\kwayi\Desktop\School\MasterArbeite_23.24\Codes\Glenn__upssss\Glenn"
output_file = output_dir + "New_hydro_rotate1.csv"

# Save the DataFrame to a CSV file
hydro1.to_csv(output_file, sep='\t')

print(f"DataFrame saved as {output_file}")
# Out:
# DataFrame saved as C:\Users\kwayi\Desktop\School\MasterArbeite_23.24\Codes\Glenn__upssss\GlennNew_hydro_rotate1.csv

# %%
hydro1.drop(columns=['Datum'], inplace=True)

# %%
hydro1.columns


hydro1 = hydro1[['datetime', 'dH [mm]', 'dH [mm].1', 'dH [mm].2', 'dH [mm].3', 'dH [mm].4',
       'dH [mm].5', 'dH [mm].6', 'dH [mm].7', 'dH [mm].8', 'dH [mm].9',
       'dH [mm].10', 'dH [mm].11', 'dH [mm].12', 'dH [mm].13', 'dH [mm].14',
       'dH [mm].15', 'dH [mm].16', 'dH [mm].17', 'dH [mm].18', 'dH [mm].19',
       'dH [mm].20', 'dH [mm].21', 'dH [mm].22', 'dH [mm].23', 'dH [mm].24',
       'dH [mm].25', 'dH [mm].26', 'dH [mm].27', 'dH [mm].28', 'dH [mm].29',
       'dH [mm].30', 'dH [mm].31', 'dH [mm].32', 'dH [mm].33', 'dH [mm].34',
       'dH [mm].35', 'dH [mm].36', 'dH [mm].37', 'dH [mm].38', 'dH [mm].39',
       'dH [mm].40', 'dH [mm].41', 'dH [mm].42', 'dH [mm].43', 'dH [mm].44',
       'dH [mm].45', 'dH [mm].46', 'dH [mm].47', 'dH [mm].48', 'dH [mm].49',
       'dH [mm].50', 'dH [mm].51', 'dH [mm].52', 'dH [mm].53', 'dH [mm].54',
       'dH [mm].55', 'dH [mm].56', 'dH [mm].57', 'dH [mm].58', 'dH [mm].59',
       'dH [mm].60', 'dH [mm].61', 'Unnamed: 63']]

# %%
# Assuming hydro1 is already defined and contains the necessary data
# Convert the datetime column to a datetime object
hydro1['datetime'] = pd.to_datetime(hydro1['datetime'])

# Plot the datetime against the first dH [mm] column
plt.figure(figsize=(12, 6))
plt.plot(hydro1['datetime'], hydro1['dH [mm]'], label='dH [mm]')
plt.xlabel('Datetime')
plt.ylabel('dH [mm]')
plt.title('Datetime vs dH [mm]')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\kwayi\anaconda3\envs\hs_nb_env\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots'  # Update with the correct path
os.makedirs(output_dir, exist_ok=True)


# Convert the datetime column to a datetime object
hydro1['datetime'] = pd.to_datetime(hydro1['datetime'])

# Define the start and end date for the time frame
start_date = pd.to_datetime('2024-02-05 09:00:00')
end_date = pd.to_datetime('2024-02-05 12:00:00')

# Filter the DataFrame for the specified time frame
filtered_hydro1 = hydro1[(hydro1['datetime'] >= start_date) & (hydro1['datetime'] <= end_date)]

# Calculate standard deviation and standard error
std_dev = np.std(filtered_hydro1['dH [mm]'])
std_error = std_dev / np.sqrt(len(filtered_hydro1['dH [mm]']))

# Plot 'dH [mm]' against 'datetime' for the filtered data
plt.figure(figsize=(8, 5))
plt.plot(filtered_hydro1['datetime'], filtered_hydro1['dH [mm]'], marker='o', linestyle='-', color='blue')
title = 'dH [mm] over Time (from 2024-02-05 09:00:00 to 2024-02-05 12:00:00)'
plt.title(title)
plt.xlabel('Datetime')
plt.ylabel('dH [mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Format the x-axis to show the full datetime
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error
textstr = f'Standard Deviation: {std_dev:.2f}\nStandard Error: {std_error:.2f}'
plt.gcf().text(0.15, 0.75, textstr, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Replace spaces and special characters in the title to create a valid filename
filename = title.replace(' ', '_').replace('[', '').replace(']', '').replace(':', '').replace('/', '') + '.png'
output_file = os.path.join(output_dir, filename)

# Save the plot
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()

print(f"Plot saved as {output_file}")
# Out:
# c:\Users\kwayi\anaconda3\envs\hs_nb_env\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Plot saved as path_to_output_directory/plots\dH_mm_over_Time_(from_2024-02-05_090000_to_2024-02-05_120000).png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots/'  # Update with the correct path
os.makedirs(output_dir, exist_ok=True)



# Convert the datetime columns to datetime objects
det_circ['datetime'] = pd.to_datetime(det_circ['datetime'])
hydro1['datetime'] = pd.to_datetime(hydro1['datetime'])

# Plot 1: Filter the dataframe to include only data up to 2024-02-05 12:00:00
end_date_plot1 = pd.to_datetime('2024-02-05 12:00:00')
filtered_data_plot1 = det_circ[det_circ['datetime'] <= end_date_plot1]

# Calculate standard deviation and standard error for plot 1
std_dev_plot1 = np.std(filtered_data_plot1['rel_diff_y[mm]'])
std_error_plot1 = std_dev_plot1 / np.sqrt(len(filtered_data_plot1['rel_diff_y[mm]']))

# Plot 2: Filter the DataFrame for the specified time frame
start_date_plot2 = pd.to_datetime('2024-02-05 10:00:00')
end_date_plot2 = pd.to_datetime('2024-02-05 12:00:00')
filtered_data_plot2 = hydro1[(hydro1['datetime'] >= start_date_plot2) & (hydro1['datetime'] <= end_date_plot2)]

# Calculate standard deviation and standard error for plot 2
std_dev_plot2 = np.std(filtered_data_plot2['dH [mm]'])
std_error_plot2 = std_dev_plot2 / np.sqrt(len(filtered_data_plot2['dH [mm]']))

# Create a figure for combined plots
plt.figure(figsize=(8, 6))

# Plot 1: 'rel_diff_x[mm]' against 'datetime'
plt.subplot(2, 1, 1)
plt.plot(filtered_data_plot1['datetime'], filtered_data_plot1['rel_diff_x[mm]'], marker='o', linestyle='-', color='blue')
title1 = 'rel_diff_y[mm] over Time (up to 2024-02-05 12:00:00)'
plt.title(title1)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error for plot 1
textstr1 = f'Standard Deviation: {std_dev_plot1:.2f}\nStandard Error: {std_error_plot1:.2f}'
plt.gcf().text(0.15, 0.75, textstr1, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Plot 2: 'dH [mm]' against 'datetime'
plt.subplot(2, 1, 2)
plt.plot(filtered_data_plot2['datetime'], filtered_data_plot2['dH [mm]'], marker='o', linestyle='-', color='blue')
title2 = 'dH [mm] over Time (from 2024-02-05 09:00:00 to 2024-02-05 12:00:00)'
plt.title(title2)
plt.xlabel('Datetime')
plt.ylabel('dH [mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error for plot 2
textstr2 = f'Standard Deviation: {std_dev_plot2:.2f}\nStandard Error: {std_error_plot2:.2f}'
plt.gcf().text(0.15, 0.35, textstr2, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Save the combined plot
filename_combined = 'combined_plot_up_to_2024-02-05_12_00_00.png'
output_file_combined = os.path.join(output_dir, filename_combined)
plt.savefig(output_file_combined, dpi=300)

# Show the combined plot
plt.show()

print(f"Combined plot saved as {output_file_combined}")
# Out:
# Combined plot saved as path_to_output_directory/plots/combined_plot_up_to_2024-02-05_12_00_00.png

# %%
# Create a directory to save the plots
output_dir = 'path_to_output_directory/plots/'  # Update with the correct path
os.makedirs(output_dir, exist_ok=True)


# Convert the datetime columns to datetime objects
det_circ['datetime'] = pd.to_datetime(det_circ['datetime'])
hydro1['datetime'] = pd.to_datetime(hydro1['datetime'])

# Define the start and end date for the time frame
start_date = pd.to_datetime('2024-02-05 12:00:00')
end_date = pd.to_datetime('2024-02-05 13:30:00')

# Filter the dataframes for the specified time frame
filtered_data_det_circ = det_circ[(det_circ['datetime'] >= start_date) & (det_circ['datetime'] <= end_date)]
filtered_data_hydro1 = hydro1[(hydro1['datetime'] >= start_date) & (hydro1['datetime'] <= end_date)]

# Calculate standard deviation and standard error for det_circ
std_dev_det_circ = np.std(filtered_data_det_circ['rel_diff_y[mm]'])
std_error_det_circ = std_dev_det_circ / np.sqrt(len(filtered_data_det_circ['rel_diff_y[mm]']))

# Calculate standard deviation and standard error for hydro1
std_dev_hydro1 = np.std(filtered_data_hydro1['dH [mm]'])
std_error_hydro1 = std_dev_hydro1 / np.sqrt(len(filtered_data_hydro1['dH [mm]']))

# Create a figure for subplots
plt.figure(figsize=(8, 6))

# Subplot 1: rel_diff_x[mm] against datetime for det_circ
plt.subplot(2, 1, 1)
plt.plot(filtered_data_det_circ['datetime'], filtered_data_det_circ['rel_diff_y[mm]'], marker='o', linestyle='-', color='blue')
plt.axhline(y=-7, color='red', linestyle='--')
plt.axhline(y=7, color='red', linestyle='--')
title1 = 'rel_diff_y[mm] over Time (from 2024-02-05 12:00:00 to 2024-02-05 13:30:00)'
plt.title(title1)
plt.xlabel('Datetime')
plt.ylabel('rel_diff_y[mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error for det_circ
textstr1 = f'Standard Deviation: {std_dev_det_circ:.2f}\nStandard Error: {std_error_det_circ:.2f}'
plt.gcf().text(0.15, 0.75, textstr1, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Subplot 2: dH [mm] against datetime for hydro1
plt.subplot(2, 1, 2)
plt.plot(filtered_data_hydro1['datetime'], filtered_data_hydro1['dH [mm]'], marker='o', linestyle='-', color='blue')
title2 = 'dH [mm] over Time (from 2024-02-05 12:00:00 to 2024-02-05 13:30:00)'
plt.title(title2)
plt.xlabel('Datetime')
plt.ylabel('dH [mm]')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())

# Add text box for standard deviation and standard error for hydro1
textstr2 = f'Standard Deviation: {std_dev_hydro1:.2f}\nStandard Error: {std_error_hydro1:.2f}'
plt.gcf().text(0.15, 0.35, textstr2, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Save the combined plot
filename_combined = 'combined_plot_from_2024-02-05_12_00_00_to_2024-02-05_13_30_00.png'
output_file_combined = os.path.join(output_dir, filename_combined)
plt.savefig(output_file_combined, dpi=300)

# Show the combined plot
plt.show()

print(f"Combined plot saved as {output_file_combined}")
# Out:
# Combined plot saved as path_to_output_directory/plots/combined_plot_from_2024-02-05_12_00_00_to_2024-02-05_13_30_00.png

# %% [markdown]
# factors to high measurement in the circle position
# - if the camera is not fixed as at the time of exposure.
# - if the vibrations are at different frequencies, the deviation in the vibrations can affect the measurement.
# - the load distribution of the flow of traffic depending on the position of the moving vehicles

# %% [markdown]
# rec
# - Line of collimation using two cameras to estimste the exact centre of the ball. forming a 3d stereo image in the end

# %%
# Image data
data = pd.read_excel("new_data/new_data/updated_fitting_centre.xlsx")
data["time"] = data["datetime"].dt.strftime('%d%H%M').astype(int)
# print(data.head(5))
data_np = data[["time","rel_diff_y[mm]"]].to_numpy()
print(data_np.shape)
# Out:
# (68, 2)

# %%
# Hydro data
data_hd = pd.read_excel("new_data/new_data/hydro.xlsx")
data_hd["datetime"] = data_hd["datetime"].astype("datetime64[ns]")
data_hd["time"] = data_hd["datetime"].dt.strftime('%d%H%M').astype(int)
data_hd_np = data_hd[["time","dH [mm]"]].to_numpy()
print(data_hd_np.shape)
# Out:
# (71, 2)

# %%
print(data_np[0])
print(data_np[1])
# Out:
# [51019.     0.]
# [ 5.10240000e+04 -4.80806623e+00]

# %%
def interpolate_data(data):
    interpolate_data = np.zeros((1,data.shape[1]))

    for i in range(data.shape[0]-1):
        val_i = data[i] # timestamp 0
        val_ii = data[i+1] # timestamp 1

        diff_pi_pii = val_ii - val_i #difference in value [time, value]

        interpolate_value = np.linspace(val_i[1], val_ii[1], int(diff_pi_pii[0]),endpoint=False).reshape(-1, 1)
        interpolate_time = np.linspace(val_i[0], val_ii[0], int(diff_pi_pii[0]),endpoint=False).reshape(-1, 1)
        
        inter_data  = np.hstack([interpolate_time,interpolate_value])
        interpolate_data  = np.vstack([interpolate_data,inter_data])
    
    return interpolate_data[1:,:]

# %%
data_img_int = interpolate_data(data_np)
data_hyd_int = interpolate_data(data_hd_np)

# %%
#plotting the original data structure


plt.figure(figsize=(20,8))
plt.plot(data_img_int[:,0],data_img_int[:,1],'--ob')
plt.plot(data_hyd_int[:,0],data_hyd_int[:,1],'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
# Assuming data_img_int and data_hyd_int are NumPy arrays
# Remove outliers greater than ±10mm in data_img_int
filtered_data_img_int = data_img_int[(data_img_int[:, 1] > -10) & (data_img_int[:, 1] < 10)]

# Align both datasets to start from the same zero line
filtered_data_img_int_aligned = filtered_data_img_int[:, 1] - filtered_data_img_int[0, 1]
data_hyd_int_aligned = data_hyd_int[:, 1] - data_hyd_int[0, 1]

# Plotting the filtered and aligned data
plt.figure(figsize=(15,8))
plt.plot(filtered_data_img_int[:,0], - filtered_data_img_int_aligned, '--ob', label='Image Data')
plt.plot(data_hyd_int[:,0], data_hyd_int_aligned, '--or', label='Hydrostatic Data')
plt.title("Hydrostatic sensor and Image Data over measurement period")
plt.ylabel("change (mm)")
plt.xlabel("time(s)")
plt.legend()

# Save the combined plot
filename_combined = 'Hydro_Image_data plot.png'
output_file_combined = os.path.join(output_dir, filename_combined)
plt.savefig(output_file_combined, dpi=300)


plt.show()

# %%
#Plotting within the timespace and not negating the detected image data


time = 51200.0
timestamp = np.argwhere(data_hyd_int[:,0]==time)[0][0]

plt.figure(figsize=(20,8))
plt.plot(data_img_int[:timestamp,0],data_img_int[:timestamp,1],'--ob')
plt.plot(data_hyd_int[:timestamp,0],data_hyd_int[:timestamp,1],'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
#Plotting within the timespace and negating the detected image data

time = 51200.0
timestamp = np.argwhere(data_hyd_int[:,0]==time)[0][0]

plt.figure(figsize=(20,8))
plt.plot(data_img_int[:timestamp,0],-data_img_int[:timestamp,1],'--ob')
plt.plot(data_hyd_int[:timestamp,0],data_hyd_int[:timestamp,1],'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
#overlaying them on eachother

time = 51200.0
timestamp = np.argwhere(data_hyd_int[:,0]==time)[0][0]
data_img_ts = data_img_int[:timestamp,:]
data_hyd_ts = data_hyd_int[:timestamp,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],-data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

#Plotting within the timespace and not negating the detected image data
#overlaying them on eachother

start_time = 51200.0
end_time = 51330.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

start_time = 51200.0
end_time = 51330.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],-data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming data_img_int and data_hyd_int are NumPy arrays

# Helper function to filter outliers and align data to start from zero
def process_data(data_img_int, data_hyd_int):
    # Remove outliers greater than ±10mm in data_img_int
    filtered_data_img_int = data_img_int[(data_img_int[:, 1] > -10) & (data_img_int[:, 1] < 10)]
    
    # Align both datasets to start from the same zero line
    filtered_data_img_int_aligned = filtered_data_img_int[:, 1] - filtered_data_img_int[0, 1]
    data_hyd_int_aligned = data_hyd_int[:, 1] - data_hyd_int[0, 1]

    return filtered_data_img_int, filtered_data_img_int_aligned, data_hyd_int_aligned

# Set the start and end times for the different plots
time_ranges = [
    (51200.0, None),   # Full dataset until 51200.0
    (51200.0, 51330.0),  # From 51200.0 to 51330.0
    (51200.0, 51330.0),  # Example duplicate for consistency in the provided code
    (51300.0, 51400.0)   # New range example
]

# Initialize the subplot figure with 2x2 grid
fig, axs = plt.subplots(2, 2, figsize=(20, 16))
axs = axs.flatten()  # Flatten to easily iterate

# Plot data for each time range
for i, (start_time, end_time) in enumerate(time_ranges):
    # Define the time range for the current subplot
    timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
    if end_time:
        timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]
    else:
        timestamp_e = len(data_hyd_int)
    
    data_img_ts = data_img_int[timestamp_s:timestamp_e, :]
    data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e, :]

    # Process data
    filtered_data_img_ts, filtered_data_img_ts_aligned, data_hyd_ts_aligned = process_data(data_img_ts, data_hyd_ts)

    # Calculate standard deviations
    std_img = np.std(filtered_data_img_ts_aligned)
    std_hyd = np.std(data_hyd_ts_aligned)

    # Plot filtered and aligned data
    axs[i].plot(filtered_data_img_ts[:,0], filtered_data_img_ts_aligned, '--ob', label='Image Data')
    axs[i].plot(data_hyd_ts[:,0], data_hyd_ts_aligned, '--or', label='Hydrostatic Data')
    axs[i].set_title(f"HydroStatic sensor & Image data plot {i+1}")
    axs[i].set_ylabel("Relative change (mm)")
    axs[i].set_xlabel("time(s)")
    axs[i].grid(True)
    
    # Display standard deviations on the bottom left of the plot
    axs[i].text(0.05, 0.05, f'Std dev Image: {std_img:.2f}, Hydro: {std_hyd:.2f}',
                transform=axs[i].transAxes, fontsize=12, verticalalignment='bottom', bbox=dict(facecolor='white', alpha=0.5))
    axs[i].legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the combined plot
filename_combined = 'Hydro_image_combined_plots_with_std_dev.png'
output_file_combined = os.path.join(output_dir, filename_combined)
plt.savefig(output_file_combined, dpi=300)

# Show the plot
plt.show()

# %%
#Plotting within the timespace and not negating the detected image data
#overlaying them on eachother

start_time = 51200.0
end_time = 51330.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
#Plotting within the timespace and negating the detected image data
#overlaying them on eachother

start_time = 51200.0
end_time = 51330.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],-data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
#Plotting within the timespace and  not negating the detected image data


start_time = 51330.0
end_time = 51600.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
#Plotting within the timespace and not negating the detected image data
#overlaying them on eachother


start_time = 51330.0
end_time = 51600.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %%
#Plotting within the timespace and negating the detected image data
#overlaying them on eachother


start_time = 51330.0
end_time = 51600.0

timestamp_s = np.argwhere(data_hyd_int[:,0]==start_time)[0][0]
timestamp_e = np.argwhere(data_hyd_int[:,0]==end_time)[0][0]

data_img_ts = data_img_int[timestamp_s:timestamp_e,:]
data_hyd_ts = data_hyd_int[timestamp_s:timestamp_e,:]

mean_diff = np.abs(np.mean(data_hyd_ts))-np.abs(np.mean(data_img_ts))

plt.figure(figsize=(20,8))
plt.plot(data_img_ts[:,0],-data_img_ts[:,1],'--ob')
plt.plot(data_hyd_ts[:,0],data_hyd_ts[:,1]-mean_diff,'--or')
plt.title("HydroStatic sensor station 1")
plt.ylabel("mm")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# Applying the bias in the x,y direction from the lab data analysis to the field data
